# %% [markdown]
# ##Since I will work with an labeled data set, I think supervised machine learning models will fit the best.

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

df = pd.read_csv("full_data.csv")

#Display the first five rows of the data of the full data.
df.head()
# Out:
#    Unnamed: 0 Cancer Type Detailed  Mutation Count  Fraction Genome Altered  \
# 0           0  Lung Adenocarcinoma             3.0                   0.1539
# 1           1  Lung Adenocarcinoma            32.0                   0.1318
# 2           2  Lung Adenocarcinoma           370.0                   0.3385
# 3           3  Lung Adenocarcinoma            72.0                   0.0758
# 4           4  Lung Adenocarcinoma           652.0                   0.3153
#
#    Diagnosis Age     Sex Somatic Status Smoking History  \
# 0           56.0  Female        Matched   Former Smoker
# 1           56.0  Female        Matched   Former Smoker
# 2           69.0    Male        Matched   Former Smoker
# 3           69.0  Female        Matched   Former Smoker
# 4           78.0    Male        Matched   Former Smoker
#
#    Person Cigarette Smoking History Pack Year Value  TMB Nonsynonymous
# 0                                         36.427867           0.066667
# 1                                         36.427867           1.066667
# 2                                         36.427867          12.466667
# 3                                         36.427867           2.400000
# 4                                         36.427867          21.800000

# %%
#Clean dataset to delete first column
df = df.iloc[:, 1:]
df.head()
# Out:
#   Cancer Type Detailed  Mutation Count  Fraction Genome Altered  \
# 0  Lung Adenocarcinoma             3.0                   0.1539
# 1  Lung Adenocarcinoma            32.0                   0.1318
# 2  Lung Adenocarcinoma           370.0                   0.3385
# 3  Lung Adenocarcinoma            72.0                   0.0758
# 4  Lung Adenocarcinoma           652.0                   0.3153
#
#    Diagnosis Age     Sex Somatic Status Smoking History  \
# 0           56.0  Female        Matched   Former Smoker
# 1           56.0  Female        Matched   Former Smoker
# 2           69.0    Male        Matched   Former Smoker
# 3           69.0  Female        Matched   Former Smoker
# 4           78.0    Male        Matched   Former Smoker
#
#    Person Cigarette Smoking History Pack Year Value  TMB Nonsynonymous
# 0                                         36.427867           0.066667
# 1                                         36.427867           1.066667
# 2                                         36.427867          12.466667
# 3                                         36.427867           2.400000
# 4                                         36.427867          21.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5071 entries, 0 to 5070
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Cancer Type Detailed                              5071 non-null   object
#  1   Mutation Count                                    5071 non-null   float64
#  2   Fraction Genome Altered                           5071 non-null   float64
#  3   Diagnosis Age                                     5071 non-null   float64
#  4   Sex                                               5071 non-null   object
#  5   Somatic Status                                    5071 non-null   object
#  6   Smoking History                                   5071 non-null   object
#  7   Person Cigarette Smoking History Pack Year Value  5071 non-null   float64
#  8   TMB Nonsynonymous                                 5071 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 356.7+ KB

# %% [markdown]
# ###A correlation matrix to calculate the pairwise correlation coefficients between all variables.

# %%
cormat = df.corr()
round(cormat,2)
# Out:
#                                                   Mutation Count  \
# Mutation Count                                              1.00
# Fraction Genome Altered                                     0.26
# Diagnosis Age                                               0.00
# Person Cigarette Smoking History Pack Year Value            0.16
# TMB Nonsynonymous                                           0.80
#
#                                                   Fraction Genome Altered  \
# Mutation Count                                                       0.26
# Fraction Genome Altered                                              1.00
# Diagnosis Age                                                       -0.05
# Person Cigarette Smoking History Pack Year Value                     0.17
# TMB Nonsynonymous                                                    0.15
#
#                                                   Diagnosis Age  \
# Mutation Count                                             0.00
# Fraction Genome Altered                                   -0.05
# Diagnosis Age                                              1.00
# Person Cigarette Smoking History Pack Year Value           0.08
# TMB Nonsynonymous                                         -0.03
#
#                                                   Person Cigarette Smoking History Pack Year Value  \
# Mutation Count                                                                                0.16
# Fraction Genome Altered                                                                       0.17
# Diagnosis Age                                                                                 0.08
# Person Cigarette Smoking History Pack Year Value                                              1.00
# TMB Nonsynonymous                                                                             0.12
#
#                                                   TMB Nonsynonymous
# Mutation Count                                                 0.80
# Fraction Genome Altered                                        0.15
# Diagnosis Age                                                 -0.03
# Person Cigarette Smoking History Pack Year Value               0.12
# TMB Nonsynonymous                                              1.00

# %% [markdown]
# ###I add a correlation matrix to heat map. The basic idea of heatmaps is that they replace numbers with colors of varying shades, as indicated by the scale on the right. Cells that are lighter have higher values of r. This type of visualization can make it much easier to spot linear relationships between variables than a table of numbers.

# %%
sns.heatmap(cormat);

# %%
# Remove the data conversion warning.
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

# %%
# Remove the Mutation Count for y.
df1 = df.drop(columns=['Mutation Count'])
y = df1

#Convert Cancer Type Detailed into numeric data
df['Cancer Type Detailed'].replace(['Lung Adenocarcinoma', 'Lung Squamos', 'Small Cell Lung Cancer', 'Lung Squamous Cell Carcinoma'],[1, 2, 3, 4], inplace=True)
#Convert Sex into numeric data
df['Sex'].replace(['Male', 'Female'],[0, 1], inplace=True)
#Convert Somatic Status into numeric data
df['Somatic Status'].replace(['Unmatched', 'Matched'],[0, 1], inplace=True)
#Convert Smoking History into numeric data
df['Smoking History'].replace(['Non Smoker', 'Former Smoker', 'Current Smoker', 'Reformed Smoker'],[0, 1, 2, 3], inplace=True)

X = df
X.head()
# Out:
#    Cancer Type Detailed  Mutation Count  Fraction Genome Altered  \
# 0                     1             3.0                   0.1539
# 1                     1            32.0                   0.1318
# 2                     1           370.0                   0.3385
# 3                     1            72.0                   0.0758
# 4                     1           652.0                   0.3153
#
#    Diagnosis Age  Sex  Somatic Status  Smoking History  \
# 0           56.0    1               1                1
# 1           56.0    1               1                1
# 2           69.0    0               1                1
# 3           69.0    1               1                1
# 4           78.0    0               1                1
#
#    Person Cigarette Smoking History Pack Year Value  TMB Nonsynonymous
# 0                                         36.427867           0.066667
# 1                                         36.427867           1.066667
# 2                                         36.427867          12.466667
# 3                                         36.427867           2.400000
# 4                                         36.427867          21.800000

# %% [markdown]
# ###Create training and test data for model evaluation

# %% [markdown]
# ###In Machine Learning, it's important as a first step to consider the nature of the problem. From my understanding, this is a regression problem because the problem I seek to solve is to determine a continuous numerical output or result. This is known as a regression problem, and, therefore, I need to use a regression algorithm.

# %% [markdown]
# ###Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression()
lr.fit(X_train, y_train)

#The “slope” parameters (w), also called weights or coefficients, are stored in the coef_
#..attribute, while the offset or intercept (b) is stored in the intercept_ attribute:

print("lr.coef_: {}".format(lr.coef_))
print("lr.intercept_: {}".format(lr.intercept_))
# Out:
# lr.coef_: [[ 1.00000000e+00 -3.19308190e-17  1.08235796e-15  2.29714002e-18
#   -3.70699352e-17 -1.24130993e-16  7.06881612e-16 -3.67534722e-17
#    1.43979933e-17]
#  [ 9.64341078e-17  3.25260652e-18  1.00000000e+00  7.46845890e-17
#    5.43789646e-16 -1.10243730e-15 -1.87070106e-15  1.14681485e-16
#   -7.06442419e-17]
#  [ 9.28466639e-16 -6.93889390e-17 -2.31238978e-15  1.00000000e+00
#   -2.75252504e-15 -4.79102376e-16 -6.61905426e-17 -1.04083409e-17
#    1.99899776e-16]
#  [-1.42872063e-18  6.93889390e-18 -1.04520986e-15 -1.24080162e-16
#    1.00000000e+00 -1.11664827e-15 -9.96517322e-17 -7.86046575e-18
#    6.30599089e-17]
#  [ 1.98328036e-17  3.38813179e-19  1.73831068e-16 -1.62974433e-18
#    2.24956254e-16  1.00000000e+00 -3.25405706e-17  6.66403171e-19
#   -1.58129272e-17]
#  [ 1.01971091e-15 -1.90819582e-17  1.70973600e-15  6.60279123e-17
#    8.49031945e-16 -3.72364869e-16  1.00000000e+00 -3.98986399e-17
#    8.63431505e-17]
#  [ 2.01761134e-15 -1.11022302e-15 -1.05448826e-14  1.37910516e-16
#   -1.09791733e-15  9.86046068e-15 -1.00297375e-14  1.00000000e+00
#   -8.42425088e-17]
#  [ 4.16511022e-16  1.04083409e-17 -6.25722720e-16  1.08420217e-19
#   -1.39684881e-15 -1.35326551e-15  1.21799272e-15  4.20670443e-17
#    1.00000000e+00]]
# lr.intercept_: [ 1.59872116e-14 -5.82867088e-15  9.94759830e-14  8.93729535e-15
#  -4.44089210e-16 -2.22044605e-16  2.13162821e-13 -5.32907052e-15]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) 
# randomly assign some data to the test-set and the rest to the training-set

X_train.head()
# Out:
#       Cancer Type Detailed  Mutation Count  Fraction Genome Altered  \
# 4412                     1             6.0                 0.044200
# 4482                     1            47.0                 0.072400
# 2060                     1            37.0                 0.258468
# 3389                     1           240.0                 0.134300
# 4475                     1             3.0                 0.179100
#
#       Diagnosis Age  Sex  Somatic Status  Smoking History  \
# 4412      64.645512    1               1                1
# 4482      64.645512    1               1                1
# 2060      60.000000    0               1                1
# 3389      70.000000    0               1                3
# 4475      58.000000    1               1                1
#
#       Person Cigarette Smoking History Pack Year Value  TMB Nonsynonymous
# 4412                                         20.000000           5.188189
# 4482                                          4.650000          40.640810
# 2060                                         36.427867           1.233333
# 3389                                         10.000000           8.066667
# 4475                                         36.427867           2.594094

# %% [markdown]
# ###I also tried the Random Forest model to prove my point that linear regression is the best model for this problem. As you can see from the warning below, a continuous-multioutput result is not what a Random Forest model could solve.

# %%
from sklearn import preprocessing

# Here, I standardize by X data using StandardScalar
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled.shape
# Out:
# (3803, 9)

# %%
dendrogram = sch.dendrogram(sch.linkage(X_train_scaled, method='ward'))
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'complete') # Here as use "complete" linkage
hc.fit(X_train_scaled)
hc.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df.head()#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100, random_state = 42)
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train_scaled,y_train)
y_pred=clf.predict(X_test_scaled)
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
#print("Accuracy on Test Data:",metrics.accuracy_score(y_test, y_pred))

model = clf
print("Random Forest Classifier's cross validation accuracy:", np.mean(cross_val_score(model, X_train_scaled, y_train, cv=10)))
print("Random Forest Classifier's Test-Data prediction accuracy: {:.5f}".format(model.score(X_test_scaled, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-c8f39eae56bd> in <module>()
#       4 clf=RandomForestClassifier(n_estimators=100, random_state = 42)
#       5 #Train the model using the training sets y_pred=clf.predict(X_test)
# ----> 6 clf.fit(X_train_scaled,y_train)
#       7 y_pred=clf.predict(X_test_scaled)
#       8 #Import scikit-learn metrics module for accuracy calculation
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     365         self.n_outputs_ = y.shape[1]
#     366
# --> 367         y, expanded_class_weight = self._validate_y_class_weight(y)
#     368
#     369         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     732
#     733     def _validate_y_class_weight(self, y):
# --> 734         check_classification_targets(y)
#     735
#     736         y = np.copy(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ValueError: Unknown label type: 'continuous-multioutput'
